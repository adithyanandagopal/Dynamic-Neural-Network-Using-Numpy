# %%
try :
    from Model import model
    print("model import done !")
except Exception as e:
    print(e)
# Out:
# model import done !

# %%
nn = model(
    structure=[784, 128, 64,10],
    base_address="./"
)
nn.fit(
    train_data="mnist_train.csv",
    test_data="mnist_test.csv",
    epoch=5,
    alpha=0.034,
    batch_size=50
)
# Out:
# data loaded!.....
# weights initialised!...
# training.....
#
#  loss = 491.2744423109583
#
#  accuracy = 88.71833333333333%
#
# -------1 epoch done------
#
#  loss = 243.1089027237752
#
#  accuracy = 94.12333333333333%
#
# -------2 epoch done------
#
#  loss = 186.11214523137465
#
#  accuracy = 95.53%
#
# -------3 epoch done------
#
#  loss = 151.59333826386532
#
#  accuracy = 96.345%
#
# -------4 epoch done------
#
#  loss = 127.52817894463607
#
#  accuracy = 96.97833333333334%
#
# -------5 epoch done------
# -------Training-------
# saved!
#  test accuracy 96.39%
